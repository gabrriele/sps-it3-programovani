# %% [markdown]
# <a href="https://colab.research.google.com/github/JaroslavHolecek/Teaching/blob/master/JupyterNotebook/SQL/Princip_relacni_databaze_a_pripojeni_zadani.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Relační databáze - princip a připojení
# Relační databáze mají jako základ tabulky. Dále jsou a tyto tabulky propojeny předem nastavenými vztahy - propojení není nic jiného, než že se hodnoty z jedné tabulky objevují v jiné tabulce.
#
# Tabulky obsahují sloupce - __atributy__ a řádky - __záznamy__.
#
# V reálném světě máme objekty (npř. auto, dům, ...) "smyšlené objekty" (např. řidičská kvalifikace, barva, ...) - jedním slovem toto "věci" nazýváme <strong>entita</strong>. Entity mají své vlastnosti - auto má značku, spz, počet kol, počet dvěří, ... .
#
# Atributy (sloupce) tabulky určují vlastnosti entit, které se do tabulky budou vkládat. Konkrétní data - tedy např. "BMW, 2A5 01, 4, 5" jsou potom záznamy (řádky) v tabulce.
#
# # SŘBD - systém řízení báze dat
# Jedná se o systém (program/aplikaci), který se "stará" o data. Jeho prací je dohlížet na to, zda do databáze zadáváme to co tam má skutečně být.
#
# Např.:
# - hlídá datové typy
# - indexuje záznamy
# - hlídá unikátní hodnoty ve sloupcích (pokud tak tabulku nastavíme)
# - hlídá data napříč 2 a více tabulkami na základě vlastních a cizích klíčů
# - a mnoho dalšího
#
# # Atribut
# Sloupeček v databázi určuje jaké informaci, kterou si budeme o entitě v databázi pamatovat/zapisovat do databáze. Abychom správně nastavili atribut musíme mu přiřadit název a datový typ, datový typ může být např.: celé číslo - int, datum - date, text - text a mnoho dalších. Dále můžeme atributu nastavit různé vlastnosti (NOT NULL, UNIQUE, ...), které si budeme ukazovat dále.
#
# Do každého atributu lze zapsat pouze jednou na každém řádku (pro každý záznam). Pokud budeme potřebovat zapsat např. 2 telefoní čísla do jednoho záznamu (k jednomu člověku v databázi), budeme muset pro druhé telefoní číslo vytvořit nový atribut (to mimochodem není nejlepší způsob, zde je pouze pro představu).
#
# Atribut jako takový by měl být atomický. To znamená, že záznam, který do atributu zadáváme nejde nijak rozložit.
#
# Např.: Máme atribut "jmeno a prijmeni"
#
# Tento atribut můžeme rozdělit na 2 samostatně stojící atriburty, na "jmeno" a na "prijmeni"
#
# Teď máme 2 atributy: "jmeno" a "prijmeni"
#
# Tyto atributy nemůžeme nijak rozdělit, jedná se tudíž o atomické atributy.
#
# Správná volba atributů (a jejich složitostí) nám zajistí hladký chod databáze její jednoduché používání a psaní dalších dotazů do databáze.
#
# Například takto může vypadat databáze s atomickými atributy.
#
# __Entita__ ->  ||        Člověk | | |
# -------------|| ------| | |
# __Atributy ->__    || __jmeno__ | __prijmeni__ | __datum_narozeni__
# __Záznam 1__ -> || Pavel | Novotný  | 1.1.1990
# __Záznam 2__ -> || Jakub | Novák    | 10.7.2002
#
#
# __pozn.__ Atributy se budou do větší hloubky probírat v dalších podkladech.

# %% [markdown]
# # Připojení do školní databáze pomocí Pythonu
# Abychom se mohli připojit do databáze pomocí Pythonu a s databází nadále pracovat, musíme si nejdříve nainstalovat knihovnu mysql.connector. To uděláme následujícím způsobem:

# %%
! pip install mysql-connector
# Tento příkaz stáhne a nainstaluje knihovnu mysql-connector

# %% [markdown]
# Nyni k samotnému připojení

# %%
import mysql.connector # tento příkaz vám umožní používat příkazy z knihovny mysql-connector

mydb = mysql.connector.connect(
    host = "url adresa databáze"
    ,user = "rekne_ucitel"
    ,password = "rekne_ucitel"
    ,database = "zavisi_na_useru"
) # tento příkaz nás připojí do databáze

mycursor = mydb.cursor() # proměnnou mycursor si můžeme představit jako myš a klávesnici, kterými zadáváme hodnoty do databáze a potvrzujeme příkazy
# Avšak samotné příkazy si ukážeme až v dalších podkladech.

# Poté co jsme se připojili a provedli potřebné operace se z databáze zase musíme odpojit.
# To uděláme pomocí těchto příkazů
mycursor.close()
mydb.close()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/Downloads/skola-pro-clone/sps-it3-programovani/venv/lib/python3.13/site-packages/mysql/connector/network.py:482, in MySQLTCPSocket.open_connection(self)
#     481 try:
# --> 482     addrinfos = socket.getaddrinfo(self.server_host,
#     483                                    self.server_port,
#     484                                    0, socket.SOCK_STREAM,
#     485                                    socket.SOL_TCP)
#     486     # If multiple results we favor IPv4, unless IPv6 was forced.
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/socket.py:975, in getaddrinfo(host, port, family, type, proto, flags)
#     974 addrlist = []
# --> 975 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     976     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 import mysql.connector # tento příkaz vám umožní používat příkazy z knihovny mysql-connector
# ----> 3 mydb = mysql.connector.connect(
#       4     host = "url adresa databáze"
#       5     ,user = "rekne_ucitel"
#       6     ,password = "rekne_ucitel"
#       7     ,database = "zavisi_na_useru"
#       8 ) # tento příkaz nás připojí do databáze
#      10 mycursor = mydb.cursor() # proměnnou mycursor si můžeme představit jako myš a klávesnici, kterými zadáváme hodnoty do databáze a potvrzujeme příkazy
#      11 # Avšak samotné příkazy si ukážeme až v dalších podkladech.
#      12
#      13 # Poté co jsme se připojili a provedli potřebné operace se z databáze zase musíme odpojit.
#      14 # To uděláme pomocí těchto příkazů
#
# File ~/Downloads/skola-pro-clone/sps-it3-programovani/venv/lib/python3.13/site-packages/mysql/connector/__init__.py:179, in connect(*args, **kwargs)
#     177     return CMySQLConnection(*args, **kwargs)
#     178 else:
# --> 179     return MySQLConnection(*args, **kwargs)
#
# File ~/Downloads/skola-pro-clone/sps-it3-programovani/venv/lib/python3.13/site-packages/mysql/connector/connection.py:95, in MySQLConnection.__init__(self, *args, **kwargs)
#      92 self._pool_config_version = None
#      94 if len(kwargs) > 0:
# ---> 95     self.connect(**kwargs)
#
# File ~/Downloads/skola-pro-clone/sps-it3-programovani/venv/lib/python3.13/site-packages/mysql/connector/abstracts.py:716, in MySQLConnectionAbstract.connect(self, **kwargs)
#     713     self.config(**kwargs)
#     715 self.disconnect()
# --> 716 self._open_connection()
#     717 self._post_connection()
#
# File ~/Downloads/skola-pro-clone/sps-it3-programovani/venv/lib/python3.13/site-packages/mysql/connector/connection.py:206, in MySQLConnection._open_connection(self)
#     204 self._protocol = MySQLProtocol()
#     205 self._socket = self._get_connection()
# --> 206 self._socket.open_connection()
#     207 self._do_handshake()
#     208 self._do_auth(self._user, self._password,
#     209               self._database, self._client_flags, self._charset_id,
#     210               self._ssl)
#
# File ~/Downloads/skola-pro-clone/sps-it3-programovani/venv/lib/python3.13/site-packages/mysql/connector/network.py:500, in MySQLTCPSocket.open_connection(self)
#     498         addrinfo = addrinfos[0]
#     499 except IOError as err:
# --> 500     raise errors.InterfaceError(
#     501         errno=2003, values=(self.get_address(), _strioerror(err)))
#     502 else:
#     503     (self._family, socktype, proto, _, sockaddr) = addrinfo
#
# InterfaceError: 2003: Can't connect to MySQL server on 'url adresa databáze:3306' (8 nodename nor servname provided, or not known)

# %% [markdown]
# # Cvičení
# Bude následovat jedno jednoduché cvičení (zatím není příliš co procvičovat...).
#
# Napište kód pro připojení a následné odpojení od školní databáze.

# %%
# TODO: Zde bude váš kód ->
import mysql.connector

mydb = mysql.connector.connect(
    host = "dbs.spsklandno.cz"
    ,user = "ja"
    ,password = "heslicko"
    ,database = "databazka"
)

mycursor = mydb.cursor()

mycursor.close()
mydb.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[2], line 4
#       1 # TODO: Zde bude váš kód ->
#       2 import mysql.connector
# ----> 4 mydb = mysql.connector.connect (
#       5     host = "dbs.spskladno.cz"
#       6     ,user = "ja"
#       7     ,password = "heslo"
#       8     ,database = "databaze-konkretni"
#       9 )
#      11 mycursor = mydb.cursor()
#      13 mycursor.close()
#
# File ~/Downloads/skola-pro-clone/sps-it3-programovani/venv/lib/python3.13/site-packages/mysql/connector/__init__.py:179, in connect(*args, **kwargs)
#     177     return CMySQLConnection(*args, **kwargs)
#     178 else:
# --> 179     return MySQLConnection(*args, **kwargs)
#
# File ~/Downloads/skola-pro-clone/sps-it3-programovani/venv/lib/python3.13/site-packages/mysql/connector/connection.py:95, in MySQLConnection.__init__(self, *args, **kwargs)
#      92 self._pool_config_version = None
#      94 if len(kwargs) > 0:
# ---> 95     self.connect(**kwargs)
#
# File ~/Downloads/skola-pro-clone/sps-it3-programovani/venv/lib/python3.13/site-packages/mysql/connector/abstracts.py:716, in MySQLConnectionAbstract.connect(self, **kwargs)
#     713     self.config(**kwargs)
#     715 self.disconnect()
# --> 716 self._open_connection()
#     717 self._post_connection()
#
# File ~/Downloads/skola-pro-clone/sps-it3-programovani/venv/lib/python3.13/site-packages/mysql/connector/connection.py:208, in MySQLConnection._open_connection(self)
#     206 self._socket.open_connection()
#     207 self._do_handshake()
# --> 208 self._do_auth(self._user, self._password,
#     209               self._database, self._client_flags, self._charset_id,
#     210               self._ssl)
#     211 self.set_converter_class(self._converter_class)
#     212 if self._client_flags & ClientFlag.COMPRESS:
#
# File ~/Downloads/skola-pro-clone/sps-it3-programovani/venv/lib/python3.13/site-packages/mysql/connector/connection.py:144, in MySQLConnection._do_auth(self, username, password, database, client_flags, charset, ssl_options)
#     137 packet = self._protocol.make_auth(
#     138     handshake=self._handshake,
#     139     username=username, password=password, database=database,
#     140     charset=charset, client_flags=client_flags,
#     141     ssl_enabled=self._ssl_active,
#     142     auth_plugin=self._auth_plugin)
#     143 self._socket.send(packet)
# --> 144 self._auth_switch_request(username, password)
#     146 if not (client_flags & ClientFlag.CONNECT_WITH_DB) and database:
#     147     self.cmd_init_db(database)
#
# File ~/Downloads/skola-pro-clone/sps-it3-programovani/venv/lib/python3.13/site-packages/mysql/connector/connection.py:177, in MySQLConnection._auth_switch_request(self, username, password)
#     175         auth_data = self._protocol.parse_auth_more_data(packet)
#     176 elif packet[4] == 255:
# --> 177     raise errors.get_exception(packet)
#
# ProgrammingError: 1045 (28000): Access denied for user 'ja'@'193-179-120-68.customers.tmcz.cz' (using password: YES)
