# %% [markdown]
# # 0
#
# Vytvořte nový flaskový server, který bude používat knihovny:
# * random
# * mysql.connector
# * os
# * PIL (Pillow)
#
# V kořenové adrese vytvoříte HTML soubor s názvem **home.html**, na kterém budou odkazy na čtyři úlohy viz body 1-4 v tomto zadání. Každé z tlačítek bude v jednom z rohů obrazovky a bude obsahovat čísla 1-4. Všechny úlohy, kromě 4 Vás vrátí zpátky na domovskou stránku.

# %%
import PIL

# %% [markdown]
# # 1 (obrázek)
#
# Vytvořte na stránce formulář, který bude přijímat **png obrázky**. Obrázek Vám uloží do složky **static/images** a zároveň Vám uloží kopii, která bude černobílá. Obecný kód na převod do černobílé máte níže.
#
# Poznámka: Využívá knihovnu Pillow

# %%
from PIL import Image

image = Image.open('image.jpg')
# Convert to grayscale
gray_image = image.convert('L')
# Save the grayscale image
gray_image.save('gray_image.jpg')

# %% [markdown]
# # 2 (Zobrazení uživatele dle ID)
#
# Vytvořte adresu **/user/"cislo"** , kde číslo je načteno z adresy URL a může se měnit. Vyberte si jakoukoli tabulku z databáze a načtěte takový záznam, kterému bude odpovídat ID zadané v adrese. Výsledek vypište do konzole a přesměrujte se zpět na Home.
#
# Příklad: 127.0.0.1:5000/users/1 --> načte první záznam z tabulky (ideálně users z hodiny pro registraci a login)

# %% [markdown]
# # 3 (vypsání do konzole)
#
# Vytvořte formulář, který Vám dovolí zadat číslo a text. Do terminálu (nikoli HTML stránky) vypište text tolikrát, kolikrát jste zadali číslo. Poté co smyčka skončí Vás stránka přesměruje na home stránku s výběrem úloh z bodu 1

# %% [markdown]
# # 4
#
# Vytvořte HTML stránku se 2 obrázky vedle sebe (obr. jakýkoli, klidně dva stejný). Pokud budete mít v programu zadáno:
#
# * proměná x = 0, tak se Vám zobrazí oba obrázky
# * proměná x = 1, tak se Vám zobrazí pouze levý obrázek
# * proměná x = 2, tak se Vám zobrazí pouze pravý obrázek
# * cokoli jiného znamená, že se Vám na stránce zobrazí text **"Bohužel při startu nastala chyba! Zkuste přepsat neznámou a restartovat server!"**
